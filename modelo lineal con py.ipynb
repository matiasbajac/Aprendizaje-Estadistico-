# %%
import pandas as pd

import matplotlib.pyplot as plt








nrc = pd.read_csv('Clases/Laboratorio 1/nrc.csv')
nrc 

nrc = nrc.rename(columns={
    'R.Rankings.5th.Percentile': 'rank',
    'Research.Activity.5th.Percentile': 'research',
    'Student.Support.Outcomes.5th.Percentile': 'student',
    'Diversity.5th.Percentile': 'diversity'
})[['rank', 'research', 'student', 'diversity']]

nrc
# Out:
#     rank  research  student  diversity
# 0     36        26        1         49
# 1     47         4       31          6
# 2     11         6       33         49
# 3     12        18       61         17
# 4     19        17       33         45
# ..   ...       ...      ...        ...
# 56    10         3        2         24
# 57     3         3       22          7
# 58    35        33       14         14
# 59    51        58        7          3
# 60    20        48        5         11
#
# [61 rows x 4 columns]

# %%
plt.scatter(nrc['research'], nrc['rank'], color='blue', alpha=0.5, label='Data points')


plt.xlabel('Research')
plt.ylabel('Rank')



plt.plot(nrc['research'], poly1d_fn(nrc['research']), color='red')




plt.scatter(nrc['student'], nrc['rank'], color='blue', alpha=0.5, label='Data points')


plt.xlabel('Student')
plt.ylabel('Rank')



plt.scatter(nrc['diversity'], nrc['rank'], color='blue', alpha=0.5, label='Data points')


plt.xlabel('Diversity')
plt.ylabel('Rank')
# Out:
# Text(0, 0.5, 'Rank')

# %%
import arviz as az

az.style.use("arviz-darkgrid")

# %%
az.plot_pair(nrc[["student", "rank", "diversity", "research" ]].to_dict("list"), marginals=True, textsize=24);

# %%
import pandas as pd

import numpy as np 

from matplotlib.pyplot import subplots

import statsmodels.api as sm

import statsmodels.formula.api as smf
est = smf.ols('rank ~ student + research + diversity', nrc).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   rank   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     17.51
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           3.53e-08
# Time:                        22:31:47   Log-Likelihood:                -229.48
# No. Observations:                  61   AIC:                             467.0
# Df Residuals:                      57   BIC:                             475.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.1025      3.359      1.817      0.075      -0.624      12.829
# ...

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'
